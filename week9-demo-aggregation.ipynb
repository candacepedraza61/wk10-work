# %%
## import library
import pandas as pd

# %%
## read the data

df = pd.read_csv("edu-loans.csv")
df.head()
# Out:
#    OPE ID                                        School academic_year State  \
# 0  100200  ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY     2020-2021    AL
# 1  100300                           FAULKNER UNIVERSITY     2020-2021    AL
# 2  100400                      UNIVERSITY OF MONTEVALLO     2020-2021    AL
# 3  100500                      ALABAMA STATE UNIVERSITY     2020-2021    AL
# 4  100700             CENTRAL ALABAMA COMMUNITY COLLEGE     2020-2021    AL
#
#     Zip Code        School Type dl_sub_rec dl_sub_#loans_disbursed  \
# 0  357621357             Public       3034                    5887
# 1  361093398  Private-Nonprofit       1289                    3733
# 2  351156000             Public        973                    1897
# 3  361045714             Public       2158                    4213
# 4  350100000             Public        223                     448
#
#   dl_sub_$loans_disbursed dl_unsub_underg_rec  ...  \
# ...

# %%
## lower case all college names
df["School"] = df["School"].str.lower()

# %%
df.head()
# Out:
#    OPE ID                                        School academic_year State  \
# 0  100200  alabama agricultural & mechanical university     2020-2021    AL
# 1  100300                           faulkner university     2020-2021    AL
# 2  100400                      university of montevallo     2020-2021    AL
# 3  100500                      alabama state university     2020-2021    AL
# 4  100700             central alabama community college     2020-2021    AL
#
#     Zip Code        School Type dl_sub_rec dl_sub_#loans_disbursed  \
# 0  357621357             Public       3034                    5887
# 1  361093398  Private-Nonprofit       1289                    3733
# 2  351156000             Public        973                    1897
# 3  361045714             Public       2158                    4213
# 4  350100000             Public        223                     448
#
#   dl_sub_$loans_disbursed dl_unsub_underg_rec  ...  \
# ...

# %%
## get info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20467 entries, 0 to 20466
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OPE ID                           20467 non-null  int64
#  1   School                           20467 non-null  object
#  2   academic_year                    20467 non-null  object
#  3   State                            18956 non-null  object
#  4   Zip Code                         20398 non-null  object
#  5   School Type                      20467 non-null  object
#  6   dl_sub_rec                       20467 non-null  object
#  7   dl_sub_#loans_disbursed          20467 non-null  object
#  8   dl_sub_$loans_disbursed          20467 non-null  object
#  9   dl_unsub_underg_rec              20467 non-null  object
#  10  dl_unsub_underg#loans_disbursed  20467 non-null  object
#  11  dl_unsub_underg$loans_disbursed  20467 non-null  object
# ...
